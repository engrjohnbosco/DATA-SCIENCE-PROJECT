# %% [markdown]
# <a href="https://colab.research.google.com/github/engrjohnbosco/DATA-SCIENCE-PROJECT/blob/main/1E_brazil_house_analyses.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries

# %%
# Import Matplotlib, pandas, and plotly
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px
from IPython.display import VimeoVideo

df1 = pd.read_csv("data/brasil-real-estate-1.csv")
df1.head()

# %%
# head
df1.head() should look like this:

# %%
# drop  nan column
df1.dropna(inplace=True)

# %%
# Create lat and lon column
df1[["lat", "lon"]] = df1["lat-lon"].str.split(",",expand=True).astype(float)

# %%
#column to create a "state" column
df1["state"] = df1["place_with_parent_names"].str.split("|", expand=True)[2]

# %%
# make price floating from string
df1["price_usd"] = (
    df1["price_usd"]
    .str.replace("$", "", regex = False)
    .str.replace(",", "")
    .astype(float)
)

# %%
# drop the transformed column
df1.drop(columns=["place_with_parent_names", "lat-lon" ], inplace=True)

# %%
# import file2
df2 = pd.read_csv("data/brasil-real-estate-2.csv")

# %%
# crewate dollar price column
df2["price_usd"] = (df2["price_brl"]/3.19).round(2)

# %%
# drop nan and br price colume
df2.drop(columns=["price_brl"], inplace=True)
df2.dropna(inplace=True)

# %%
# Concate df1 and df2
df = df = pd.concat([df1, df2])
print("df shape:", df.shape)
)

# %%
# plot mapbox
fig = px.scatter_mapbox(
    df,
    lat="lat",
    lon="lon",
    center={"lat": -14.2, "lon": -51.9},  # Map will be centered on Brazil
    width=600,
    height=600,
    hover_data=["price_usd"],  # Display price when hovering mouse over house
)

fig.update_layout(mapbox_style="open-street-map")

fig.show()


#Use the describe method to create a DataFrame
summary_stats =  df[["area_m2", "price_usd"]].describe()
summary_stats



# Don't change the code below 👇
fig, ax = plt.subplots()

# Build histogram
ax.hist(df["price_usd"].iloc[:20000])

# Label axes
plt.xlabel("Price [USD]")
plt.ylabel("Frequency")

# Add title
plt.title("Distribution of Home Prices")
Text(0.5, 1.0, 'Distribution of Home Prices')


# Don't change the code below 👇
fig, ax = plt.subplots()

#Build box plot
ax.boxplot(df["area_m2"], vert=False)
# plt.boxplot(df["price_usd"], vert=False)
# Label x-axis
plt.xlabel("Area [sq meters]")

# Add title
plt.title("Distribution of Home Prices")


#Use the groupby method to create a Series
mean_price_by_region = (
    df.groupby("region")
    ["price_usd"].mean()
    .sort_values(ascending=True)


)
mean_price_by_region

# Don't change the code below 👇
fig, ax = plt.subplots()


# Build bar chart, label axes, add title
mean_price_by_region.plot(
    kind="bar",
    xlabel="Region",
    ylabel="Mean Price [USD]",
    title="Mean Home Price by Region", ax=ax)

#Create a DataFrame  for southern homes
df_south = df[df["region"] == "South"]
df_south.head()

#Use the value_counts method to create a Series  for homes in df_south
homes_by_state = df_south["state"].value_counts().head(10)
homes_by_state


# Subset data
df_south_rgs = df_south[df_south["state"] == "Rio Grande do Sul"]

# Don't change the code below 👇
fig, ax = plt.subplots()

# Build scatter plot
ax.scatter(df_south_rgs["area_m2"], df_south_rgs["price_usd"])

# Label axes
plt.ylabel("Price [USD]")
plt.xlabel("Area [sq meters]")

# Add title
ax.set_title("Rio Grande do Sul: Price vs. Area")


#Create a dictionary of corr coef between area and price

south_states_corr = south_states = ["Paraná", "Rio Grande do Sul", "Santa Catarina"]

south_states_corr = {
    state: df[df["state"] == state]["area_m2"].corr(
        df[df["state"] == state]["price_usd"]
    )
    for state in south_states
}



south_states_corr
